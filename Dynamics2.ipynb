# %% [markdown]
# ##Potential-Density Pairs

# %%
import numpy as np
import matplotlib.pyplot as plt

#conversion to internal unit 
G = 6.67 * 10**8 
M = 2 * 10**33 
L = 7 * 10**10 

t = np.sqrt(L**3/(G*M))
t
# Out:
# 1.6035006681643755e-05

# %%
#free fall time 
volume = 4/3*np.pi*r^3
rho = total_mass / volume 
t = np.sqrt(1/(G*rho))

# %%
#generating random points in a sphere
M = 1 
N = 100 
A = 1 
U = np.random.uniform(0,1,N)

r = A * U**(1/3)
phi = 2 * np.pi * np.random.uniform(0,1,N)
cos_theta = np.random.uniform(-1,1,N)
theta = np.arccos(cos_theta)

x = r * np.sin(theta) * np.cos(phi)
y = r * np.sin(theta) * np.sin(phi)
z = r * np.cos(theta)

positions = np.column_stack((x,y,z))
velocities = np.zeros((N,3))
m_i = np.full(N,M/N)

input_data = np.column_stack((m_i,positions,velocities))

header_text = f"{N}\n.0.0"

np.savetxt('C:/Users/user/Downloads/sphere.in', input_data, header=header_text, comments="")
